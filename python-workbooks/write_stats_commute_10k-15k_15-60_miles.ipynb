# %% [markdown]
# ## Create the Statistics Files

# %%
import pandas as pd
from pathlib import Path
import zipfile

# %%
ODpath = Path("../data/OD/")
OD_file = ODpath.joinpath("od_distance_1k-15k_15-60_miles.csv")
if OD_file.exists ():
    print ("OD file exist")
else:
    print ("OD file does not exist")
# Out:
# OD file exist

# %%
# %time df = pd.read_csv(OD_file, dtype={'w_geocode': str,'h_geocode':str})
# Out:
# Wall time: 44.5 s

# %%
df_w_counts = pd.DataFrame(df,columns=['w_geocode','w_group_count'])

# %%
df_w_counts_unique = df_w_counts.drop_duplicates()
df_w_counts_unique.head()
# Out:
#            w_geocode  w_group_count
# 0    020200007023012           1548
# 150  020200011001027           2829
# 486  020200011001035           1852
# 742  020200011001037           1547
# 927  020200015003001           1447

# %% [markdown]
# #### Classify distance ranges

# %%
def assign_distance (df):
    if df.distance < 32000 :
        return 'short_commute'
    if df.distance > 46000 :
        return 'long_commute'
    else :
        return 'medium_commute'

# %%
df['commute_length'] = df.apply (lambda df: assign_distance(df), axis=1)

# %%
df_geocode = df.drop(['h_lat', 'h_lon', 'w_lat', 'w_lon','distance','h_geocode','state'],axis=1)
df_geocode.head()
# Out:
#          w_geocode  S000  SA01  SA02  SA03  SE01  SE02  SE03  SI01  SI02  \
# 0  020200007023012     2     1     0     1     0     2     0     0     1
# 1  020200007023012     1     0     0     1     1     0     0     0     1
# 2  020200007023012     1     0     1     0     0     1     0     0     0
# 3  020200007023012     4     1     1     2     0     3     1     0     4
# 4  020200007023012     1     0     0     1     1     0     0     0     1
#
#    SI03  w_group_count commute_length
# 0     1           1548  short_commute
# 1     0           1548  short_commute
# 2     1           1548  short_commute
# 3     0           1548  short_commute
# 4     0           1548  short_commute

# %%
ODpath = Path("../data/OD/")
OD_file_out = ODpath.joinpath("commute_length_with_1k-15k_od_stats_15-60_miles.csv")
df_geocode.to_csv(OD_file_out, index=None)

# %% [markdown]
# #### Group the data on geocode column

# %%
df_group_w_geocode = df_geocode.groupby(['w_geocode','commute_length','w_group_count']).sum()

df_group_w_geocode.reset_index(inplace = True)
df_group_w_geocode.head()
# Out:
#          w_geocode  commute_length  w_group_count  S000  SA01  SA02  SA03  \
# 0  010010205001001    long_commute           1076   124    62    45    17
# 1  010010205001001  medium_commute           1076    45    21    20     4
# 2  010010205001001   short_commute           1076    72    35    30     7
# 3  010030112023027    long_commute           1069    49    10    35     4
# 4  010030112023027  medium_commute           1069   126    21    79    26
#
#    SE01  SE02  SE03  SI01  SI02  SI03
# 0    61    51    12     0    71    53
# 1    22    13    10     0    19    26
# 2    33    25    14     0    28    44
# 3     3    20    26     0     0    49
# 4    13    44    69     0     0   126

# %%
ODpath = Path("../data/OD/")
OD_file_out = ODpath.joinpath("geocode_1k-15k_od_stats_15-60_miles.csv")
df_group_w_geocode.to_csv(OD_file_out, index=None)

# %% [markdown]
# #### Load the centroid file to dataframe for merging lat lng

# %%
blockPath = Path("../data/blocks/")
block_file = blockPath.joinpath("block_centroids.csv.gz")
if block_file.exists ():
    print ("Block Centroid file exist")
else:
    print ("Block Centroid file does not exist")
# Out:
# Block Centroid file exist

# %%
# load the centroid file
centroids = pd.read_csv(block_file, dtype={'block_geoid': 'object', 'lat': 'float', 'lon': 'float'})

# %% [markdown]
# #### Merge with df to get the lat lon assigned to the w_geocode

# %%
merge_4latlng = pd.merge(df_group_w_geocode, centroids,left_on=  ['w_geocode'],right_on= ['block_geoid'],how = 'left')
merge_4latlng.head()
# Out:
#          w_geocode  commute_length  w_group_count  S000  SA01  SA02  SA03  \
# 0  010010205001001    long_commute           1076   124    62    45    17
# 1  010010205001001  medium_commute           1076    45    21    20     4
# 2  010010205001001   short_commute           1076    72    35    30     7
# 3  010030112023027    long_commute           1069    49    10    35     4
# 4  010030112023027  medium_commute           1069   126    21    79    26
#
#    SE01  SE02  SE03  SI01  SI02  SI03      block_geoid        lat        lon
# 0    61    51    12     0    71    53  010010205001001  32.456740 -86.415025
# 1    22    13    10     0    19    26  010010205001001  32.456740 -86.415025
# 2    33    25    14     0    28    44  010010205001001  32.456740 -86.415025
# 3     3    20    26     0     0    49  010030112023027  30.518815 -87.888250
# 4    13    44    69     0     0   126  010030112023027  30.518815 -87.888250

# %%
df_merged = merge_4latlng.drop(['block_geoid'],axis=1)
df_merged.head()
# Out:
#          w_geocode  commute_length  w_group_count  S000  SA01  SA02  SA03  \
# 0  010010205001001    long_commute           1076   124    62    45    17
# 1  010010205001001  medium_commute           1076    45    21    20     4
# 2  010010205001001   short_commute           1076    72    35    30     7
# 3  010030112023027    long_commute           1069    49    10    35     4
# 4  010030112023027  medium_commute           1069   126    21    79    26
#
#    SE01  SE02  SE03  SI01  SI02  SI03        lat        lon
# 0    61    51    12     0    71    53  32.456740 -86.415025
# 1    22    13    10     0    19    26  32.456740 -86.415025
# 2    33    25    14     0    28    44  32.456740 -86.415025
# 3     3    20    26     0     0    49  30.518815 -87.888250
# 4    13    44    69     0     0   126  30.518815 -87.888250

# %% [markdown]
# #### Are there any nulls?

# %%
df_null = df_merged[df_merged.isnull().any(axis=1)]
print ('\nthe number of null records:', "{:,}".format(len(df_null)),'\n\n')
df_null.head()
# Out:
# the number of null records: 299
#            w_geocode  commute_length  w_group_count  S000  SA01  SA02  SA03  \
# 486  020200007023012    long_commute           1548    88    37    41    10
# 487  020200007023012  medium_commute           1548    76    35    30    11
# 488  020200007023012   short_commute           1548    23     8     8     7
# 489  020200011001027    long_commute           2829   301    30   206    65
# 490  020200011001027  medium_commute           2829   115     8    74    33
#
#      SE01  SE02  SE03  SI01  SI02  SI03  lat  lon
# 486    21    54    13     0    72    16  NaN  NaN
# 487    22    39    15     1    55    20  NaN  NaN
# 488     8    12     3     0    17     6  NaN  NaN
# 489     9    29   263     7     0   294  NaN  NaN
# 490     5     9   101     5     0   110  NaN  NaN

# %% [markdown]
# #### Remove rows with any nulls

# %%
df_stats_clean = df_merged.dropna(how='any')
df_null = df_merged[df_merged.isnull().any(axis=1)]
df_stats_clean.head()
# Out:
#          w_geocode  commute_length  w_group_count  S000  SA01  SA02  SA03  \
# 0  010010205001001    long_commute           1076   124    62    45    17
# 1  010010205001001  medium_commute           1076    45    21    20     4
# 2  010010205001001   short_commute           1076    72    35    30     7
# 3  010030112023027    long_commute           1069    49    10    35     4
# 4  010030112023027  medium_commute           1069   126    21    79    26
#
#    SE01  SE02  SE03  SI01  SI02  SI03        lat        lon
# 0    61    51    12     0    71    53  32.456740 -86.415025
# 1    22    13    10     0    19    26  32.456740 -86.415025
# 2    33    25    14     0    28    44  32.456740 -86.415025
# 3     3    20    26     0     0    49  30.518815 -87.888250
# 4    13    44    69     0     0   126  30.518815 -87.888250

# %%
len(df_stats_clean)
# Out:
# 47922

# %% [markdown]
# #### Write the block level stats

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_block_stats_15-60_miles.csv")
df_stats_clean.to_csv(OD_file_out, index=None)

# %% [markdown]
# #### Sum the records for each state

# %%
df_state_group = df.groupby(['state']).sum()

# %%
len(df_state_group)
# Out:
# 50

# %%
df_state_group.columns
# Out:
# Index(['distance', 'S000', 'SA01', 'SA02', 'SA03', 'SE01', 'SE02', 'SE03',
#        'SI01', 'SI02', 'SI03', 'w_lat', 'w_lon', 'h_lat', 'h_lon',
#        'w_group_count'],
#       dtype='object')

# %%
df_state_group.drop(['distance','w_group_count','w_lat', 'w_lon', 'h_lat', 'h_lon'], axis=1, inplace=True)
df_state_group.head()
# Out:
#           S000    SA01    SA02    SA03    SE01    SE02    SE03    SI01  \
# state
# 1        89880   17272   55109   17499    8909   26800   54171   27751
# 2        10475    1391    6523    2561     820    1866    7789    2259
# 4       273039   48172  166761   58106   33592   82583  156864   30008
# 5        45503    8380   27215    9908    4970   16985   23548    9160
# 6      1398046  253404  846624  298018  155886  322679  919481  186836
#
#          SI02    SI03
# state
# 1        9490   52639
# 2        1230    6986
# 4       47834  195197
# 5        4586   31757
# 6      227706  983504

# %% [markdown]
# #### Write the state level stats

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_state_stats_18-60_miles.csv")
df_state_group.to_csv(OD_file_out)

# %% [markdown]
# #### Count the number of records for each state

# %%
df['count'] = 1

# %%
df.head()
# Out:
#          w_geocode        h_geocode  distance  S000  SA01  SA02  SA03  SE01  \
# 0  020200007023012  020200001011055     31749     2     1     0     1     0
# 1  020200007023012  020200001012050     28342     1     0     0     1     1
# 2  020200007023012  020200001012064     27888     1     0     1     0     0
# 3  020200007023012  020200001013004     28501     4     1     1     2     0
# 4  020200007023012  020200001013006     28019     1     0     0     1     1
#
#    SE02  SE03  ...   SI02  SI03   w_lat    w_lon   h_lat    h_lon  state  \
# 0     2     0  ...      1     1  61.212 -149.742  61.436 -149.375      2
# 1     0     0  ...      1     0  61.212 -149.742  61.411 -149.414      2
# 2     1     0  ...      0     1  61.212 -149.742  61.413 -149.431      2
# 3     3     1  ...      4     0  61.212 -149.742  61.426 -149.452      2
# 4     0     0  ...      1     0  61.212 -149.742  61.417 -149.440      2
#
#    w_group_count  commute_length count
# 0           1548   short_commute     1
# 1           1548   short_commute     1
# 2           1548   short_commute     1
# 3           1548   short_commute     1
# 4           1548   short_commute     1
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['w_geocode', 'h_geocode', 'distance', 'S000', 'SA01', 'SA02', 'SA03',
#        'SE01', 'SE02', 'SE03', 'SI01', 'SI02', 'SI03', 'w_lat', 'w_lon',
#        'h_lat', 'h_lon', 'state', 'w_group_count', 'commute_length', 'count'],
#       dtype='object')

# %%
df_state_count = df[['state', 'count']]

# %%
len(df_state_count)
# Out:
# 8383570

# %%
df_state_counts = df_state_count.groupby(['state']).sum()

# %%
df_state_counts
# Out:
#          count
# state
# 1        76861
# 2         6903
# 4       245061
# 5        39191
# 6      1319032
# 8       144477
# 9        96917
# 10       20091
# 11       83493
# 12      486561
# 13      366312
# 15        8894
# 16       12345
# 17      513626
# 18      151314
# 19       45939
# 20       41184
# 21       77262
# 22       71141
# 23       19219
# 24      190518
# 25      253557
# 26      318153
# 27      157382
# 28       42343
# 29      102888
# 30        1956
# 31       20534
# 32       22336
# 33       23981
# 34      283564
# 35       16440
# 36      556459
# 37      212300
# 38        2838
# 39      280064
# 40       58082
# 41       38657
# 42      272580
# 44       11043
# 45       90214
# 46        6229
# 47      158160
# 48      865581
# 49       70598
# 50        5270
# 51      199033
# 53      165277
# 54       15729
# 55      115981

# %% [markdown]
# #### Write the state counts

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_state_counts_15-60_miles.csv")
df_state_counts.to_csv(OD_file_out)
