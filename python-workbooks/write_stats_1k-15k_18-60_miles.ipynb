# %% [markdown]
# ## Create the Statistics Files

# %%
import pandas as pd
from pathlib import Path
import zipfile

# %%
ODpath = Path("../data/OD/")
OD_file = ODpath.joinpath("od_distance_1k-15k_18-60_miles.csv")
if OD_file.exists ():
    print ("OD file exist")
else:
    print ("OD file does not exist")
# Out:
# OD file exist

# %%
# %time df = pd.read_csv(OD_file, dtype={'w_geocode': str,'h_geocode':str})
# Out:
# Wall time: 34.4 s

# %% [markdown]
# #### Group the data on geocode column

# %%
df_group = df.groupby(['w_geocode']).sum()

# %%
df_group.head()
# Out:
#                  distance  w_group_count  S000  SA01  SA02  SA03  SE01  SE02  \
# w_geocode
# 010010205001001  10829720         190452   182    91    68    23    91    68
# 010030112023027   8222942         206317   219    42   139    38    18    87
# 010030115021041  12166034         249613   221    98    93    30   121    71
# 010059505002038  10209278         211139   242    71   135    36    22   151
# 010150007002053   5740896         140660   137    23    87    27    20    30
#
#                  SE03  SI01  SI02  SI03     w_lat      w_lon     h_lat  \
# w_geocode
# 010010205001001    23     0    94    88  5744.889 -15295.455  5756.955
# 010030112023027   114     0     0   219  5890.167 -16962.384  5931.519
# 010030115021041    29     0   138    83  6408.703 -18501.535  6482.335
# 010059505002038    69   242     0     0  6328.399 -16981.267  6325.345
# 010150007002053    87     0     0   137  4380.610 -11157.120  4391.850
#
#                      h_lon  state
# w_geocode
# 010010205001001 -15271.453    177
# 010030112023027 -16967.225    193
# 010030115021041 -18579.621    211
# 010059505002038 -17010.630    199
# 010150007002053 -11173.799    130

# %%
df_group.columns
# Out:
# Index(['distance', 'w_group_count', 'S000', 'SA01', 'SA02', 'SA03', 'SE01',
#        'SE02', 'SE03', 'SI01', 'SI02', 'SI03', 'w_lat', 'w_lon', 'h_lat',
#        'h_lon', 'state'],
#       dtype='object')

# %%
df_group.drop(['distance','w_group_count','w_lat', 'w_lon', 'h_lat', 'h_lon'], axis=1, inplace=True)

# %%
df_group.head()
# Out:
#                  S000  SA01  SA02  SA03  SE01  SE02  SE03  SI01  SI02  SI03  \
# w_geocode
# 010010205001001   182    91    68    23    91    68    23     0    94    88
# 010030112023027   219    42   139    38    18    87   114     0     0   219
# 010030115021041   221    98    93    30   121    71    29     0   138    83
# 010059505002038   242    71   135    36    22   151    69   242     0     0
# 010150007002053   137    23    87    27    20    30    87     0     0   137
#
#                  state
# w_geocode
# 010010205001001    177
# 010030112023027    193
# 010030115021041    211
# 010059505002038    199
# 010150007002053    130

# %%
ODpath = Path("../data/OD/")
OD_file_out = ODpath.joinpath("1k-10k_od_stats_18-60_miles.csv")
df_group.to_csv(OD_file_out, index=None)

# %% [markdown]
# #### Load the centroid file to dataframe for merging lat lng

# %%
blockPath = Path("../data/blocks/")
block_file = blockPath.joinpath("block_centroids.csv.gz")
if block_file.exists ():
    print ("Block Centroid file exist")
else:
    print ("Block Centroid file does not exist")
# Out:
# Block Centroid file exist

# %%
# load the centroid file
centroids = pd.read_csv(block_file, dtype={'block_geoid': 'object', 'lat': 'float', 'lon': 'float'})

# %% [markdown]
# #### Merge with df to get the lat lon assigned to the w_geocode

# %%
merge_4latlng = pd.merge(df_group, centroids,left_on=  ['w_geocode'],right_on= ['block_geoid'],how = 'left')
merge_4latlng.head()
# Out:
#    S000  SA01  SA02  SA03  SE01  SE02  SE03  SI01  SI02  SI03  state  \
# 0   182    91    68    23    91    68    23     0    94    88    177
# 1   219    42   139    38    18    87   114     0     0   219    193
# 2   221    98    93    30   121    71    29     0   138    83    211
# 3   242    71   135    36    22   151    69   242     0     0    199
# 4   137    23    87    27    20    30    87     0     0   137    130
#
#        block_geoid        lat        lon
# 0  010010205001001  32.456740 -86.415025
# 1  010030112023027  30.518815 -87.888250
# 2  010030115021041  30.372959 -87.684560
# 3  010059505002038  31.801006 -85.332896
# 4  010150007002053  33.696812 -85.824191

# %%
merge_4latlng.columns
# Out:
# Index(['S000', 'SA01', 'SA02', 'SA03', 'SE01', 'SE02', 'SE03', 'SI01', 'SI02',
#        'SI03', 'state', 'block_geoid', 'lat', 'lon'],
#       dtype='object')

# %%
len(merge_4latlng)
# Out:
# 15991

# %% [markdown]
# #### Are there any nulls?

# %%
df_null = merge_4latlng[merge_4latlng.isnull().any(axis=1)]
print ('\nthe number of null records:', "{:,}".format(len(df_null)),'\n\n')
df_null.head()
# Out:
# the number of null records: 0
# Empty DataFrame
# Columns: [S000, SA01, SA02, SA03, SE01, SE02, SE03, SI01, SI02, SI03, state, block_geoid, lat, lon]
# Index: []

# %% [markdown]
# #### Remove rows with any nulls

# %%
df_stats_clean = merge_4latlng.dropna(how='any')
df_null = merge_4latlng[merge_4latlng.isnull().any(axis=1)]
df_stats_clean.head()
# Out:
#    S000  SA01  SA02  SA03  SE01  SE02  SE03  SI01  SI02  SI03  state  \
# 0   182    91    68    23    91    68    23     0    94    88    177
# 1   219    42   139    38    18    87   114     0     0   219    193
# 2   221    98    93    30   121    71    29     0   138    83    211
# 3   242    71   135    36    22   151    69   242     0     0    199
# 4   137    23    87    27    20    30    87     0     0   137    130
#
#        block_geoid        lat        lon
# 0  010010205001001  32.456740 -86.415025
# 1  010030112023027  30.518815 -87.888250
# 2  010030115021041  30.372959 -87.684560
# 3  010059505002038  31.801006 -85.332896
# 4  010150007002053  33.696812 -85.824191

# %%
len(df_stats_clean)
# Out:
# 15991

# %% [markdown]
# #### Write the block level stats

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_block_stats_18-60_miles.csv")
df_stats_clean.to_csv(OD_file_out, index=None)

# %% [markdown]
# #### Sum the records for each state

# %%
df_state_group = df.groupby(['state']).sum()

# %%
len(df_state_group)
# Out:
# 48

# %%
df_state_group.columns
# Out:
# Index(['distance', 'w_group_count', 'S000', 'SA01', 'SA02', 'SA03', 'SE01',
#        'SE02', 'SE03', 'SI01', 'SI02', 'SI03', 'w_lat', 'w_lon', 'h_lat',
#        'h_lon'],
#       dtype='object')

# %%
df_state_group.drop(['distance','w_group_count','w_lat', 'w_lon', 'h_lat', 'h_lon'], axis=1, inplace=True)
df_state_group.head()
# Out:
#           S000    SA01    SA02    SA03    SE01    SE02    SE03    SI01  \
# state
# 1        70038   13835   42671   13532    7317   20851   41870   22240
# 4       193230   33810  118291   41129   24062   58434  110734   22089
# 5        36380    6795   21745    7840    4057   13586   18737    7623
# 6      1118198  206464  675004  236730  127783  258149  732266  148751
# 8       115920   18791   69755   27374   13261   28873   73786   12816
#
#          SI02    SI03
# state
# 1        7675   40123
# 4       33975  137166
# 5        3409   25348
# 6      186992  782455
# 8       17619   85485

# %% [markdown]
# #### Write the state level stats

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_state_stats_18-60_miles.csv")
df_state_group.to_csv(OD_file_out)

# %% [markdown]
# #### Count the number of records for each state

# %%
df['count'] = 1

# %%
df.head()
# Out:
#          w_geocode        h_geocode  distance  w_group_count  S000  SA01  \
# 0  010010205001001  010010209001002     29897           1076     1     0
# 1  010010205001001  010010209001003     31216           1076     1     1
# 2  010010205001001  010010210001116     46757           1076     1     0
# 3  010010205001001  010010210002037     34627           1076     1     1
# 4  010010205001001  010010210002092     30628           1076     1     1
#
#    SA02  SA03  SE01  SE02  SE03  SI01  SI02  SI03   w_lat   w_lon   h_lat  \
# 0     1     0     0     1     0     0     1     0  32.457 -86.415  32.694
# 1     0     0     1     0     0     0     0     1  32.457 -86.415  32.704
# 2     1     0     0     1     0     0     0     1  32.457 -86.415  32.573
# 3     0     0     0     1     0     0     0     1  32.457 -86.415  32.668
# 4     0     0     1     0     0     0     0     1  32.457 -86.415  32.603
#
#     h_lon  state  count
# 0 -86.567      1      1
# 1 -86.573      1      1
# 2 -86.893      1      1
# 3 -86.687      1      1
# 4 -86.691      1      1

# %%
df.columns
# Out:
# Index(['w_geocode', 'h_geocode', 'distance', 'w_group_count', 'S000', 'SA01',
#        'SA02', 'SA03', 'SE01', 'SE02', 'SE03', 'SI01', 'SI02', 'SI03', 'w_lat',
#        'w_lon', 'h_lat', 'h_lon', 'state', 'count'],
#       dtype='object')

# %%
df_state_count = df[['state', 'count']]

# %%
len(df_state_count)
# Out:
# 6518356

# %%
df_state_counts = df_state_count.groupby(['state']).sum()

# %%
df_state_counts
# Out:
#          count
# state
# 1        61640
# 4       174310
# 5        32169
# 6      1064791
# 8       108828
# 9        75195
# 10       16374
# 11       65361
# 12      365059
# 13      290964
# 16        9612
# 17      410557
# 18      116594
# 19       38773
# 20       33102
# 21       62439
# 22       59328
# 23       16077
# 24      150493
# 25      198522
# 26      247896
# 27      112637
# 28       35356
# 29       76125
# 30        1538
# 31       17236
# 32       12231
# 33       18942
# 34      228095
# 35       13225
# 36      444323
# 37      165005
# 38        2550
# 39      214314
# 40       44403
# 41       29007
# 42      207554
# 44        7512
# 45       70852
# 46        5369
# 47      122419
# 48      650706
# 49       56773
# 50        4568
# 51      146069
# 53      126829
# 54       12980
# 55       93654

# %% [markdown]
# #### Write the state counts

# %%
OD_file_out = ODpath.joinpath("1k-15k_od_state_counts_18-60_miles.csv")
df_state_counts.to_csv(OD_file_out)
